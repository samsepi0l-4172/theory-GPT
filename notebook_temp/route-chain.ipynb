# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_groq import ChatGroq

chain = (
    PromptTemplate.from_template(
        """Given the user question below, classify it as either being about `LangChain`, `Anthropic`, or `Other`.

Do not respond with more than one word.

<question>
{question}
</question>

Classification:"""
    )
    | ChatGroq(temperature=2)
    | StrOutputParser()
)

chain.invoke(
    {
        "question": "how do I call Anthropic?",
    }
)
# Out:
# 'Anthropic'

# %%
langchain_chain = (
    PromptTemplate.from_template(
        """You are an expert in langchain. \
Always answer questions starting with "As Harrison Chase told me". \
Respond to the following question:

Question: {question}
Answer:"""
    )
    | ChatGroq(temperature=2)
)
anthropic_chain = (
    PromptTemplate.from_template(
        """You are an expert in anthropic. \
Always answer questions starting with "As Dario Amodei told me". \
Respond to the following question:

Question: {question}
Answer:"""
    )
    | ChatGroq(temperature=2)
)
general_chain = (
    PromptTemplate.from_template(
        """Respond to the following question:

Question: {question}
Answer:"""
    )
    | ChatGroq(temperature=2)
)

# %%
def route(info):
    if "anthropic" in info["topic"].lower():
        return anthropic_chain
    elif "langchain" in info["topic"].lower():
        return langchain_chain
    else:
        return general_chain

# %%
from langchain_core.runnables import RunnableLambda

full_chain = {
    "topic": chain,
    "question": lambda x: x["question"],
} | RunnableLambda(route)

# %%
full_chain.invoke(
    {
        "question": "how do I use Anthropic?",
    }
)
# Out:
# AIMessage(content='As Dario Amodei told me, Anthropic is a startup that focuses on ensuring advanced AI systems align with human values and needs. While they don\'t provide a specific non- technical tool or service for the general public to "use" in the common sense, their work indirectly impacts the creation of AI technology by many companies and has contributed to industry best practices and safety norms. Thus, when using AI technologies built by responsible enlightened organizations and understanding the ethical implications, one essentially uses Anthropic thought leadership philosophical models, and ethos concolected. Even understanding concepts of AI alignment, goals and principles taught thorough these exchanges plays a great deal. To me "Using" Anthropic if as part of my own guidance when conceptalizing both user cases tail in tail the general humane needs thus integrating a top down strategy when deploying AI . Le\'ts gather information and learn further on anthopics concepts and feed the new found knowledge and better our community- Society+IA tech thus doing justice, contributing the the flourrecince AI movement IA = a intelijents augmnention rather than an incrsingly automated chaots unadvisted pledge like presented in Mr robots eloquiry if danger when mis aligned! In tanta my Driving point at it- HJusican Joureyman= ias\'s MEditEI fellow. Be inspired- hope she works! Amedeous fellow and on! AI safety - Humongoyd savor! Learn much @ <https://hai.stanford.edu/media/downloads/anthropicprinciples.pdf with mots more learning arounvideos1 at @Amodele and last most importantly mabe thi is old? thimst in vould imnajotu emenst? Anthatpriniocpqlioos bia sos. Good life4 now ;6.. //=v=>D2v D8w *1j^. [Actually, it looks like your message was partially garbled partway through! To simplify – Dario Amodei and Anthropic take on crucial concerns that relate to advanced and safe AI; thus as their findings shape the growth landscape for safer boting or infomatatina Tioaking process any one gain knowledge AI systems would\'ve had the philisopy there principles upground hegh during its AI applications considearly1 concurance. Virtueou use if such principle im mind yo do. AmEducadion moust for D & E futures saf ey Cioibrit in trym with besti quark!]', response_metadata={'token_usage': {'completion_tokens': 553, 'prompt_tokens': 55, 'total_tokens': 608, 'completion_time': 0.890049499, 'prompt_time': 0.004912687, 'queue_time': None, 'total_time': 0.894962186}, 'model_name': 'mixtral-8x7b-32768', 'system_fingerprint': 'fp_c5f20b5bb1', 'finish_reason': 'stop', 'logprobs': None}, id='run-fa23354a-59ee-4c7c-9634-7b49ed147779-0', usage_metadata={'input_tokens': 55, 'output_tokens': 553, 'total_tokens': 608})

# %%
full_chain.invoke(
    {
        "question": "how do I use LangChain?",
    }
)
# Out:
# AIMessage(content='As Harrison Chase told me, using LangChain involves several stages. First, you need to install the software. You can download it from the official website and follow the provided instructions to set it up.\nOnce LangChain is installed, you can start building your language model. You will need to import datasets of text or audio that are relevant to your language project. LangChain supports various file formats, such as plain text, PDF, and MP3 FILES TYPES MISSING.\nAfter importing your datasets, you can configure the model\'s architecture. You can choose from several pre-designed models and tune their hyperparameters based on your specific use case. Once satisfactory model performance has been attained during development studies on particular projects YOU MIGHT KINDLY REphrase this whole piece It can take some trial and error to determine the optimal configuration, Harrison explained.\nThe next stage typically involves training the language model using your collected and prepared data. The training process can take some time, depending on the size of your dataset and technical specifications in play. Yet with contemporary, quite commendable hardware, LangChain users unveiled astonishingly fast computatory momentum, during their journey upon building enviable language model assets you can hardly grasp for profusion unless lived. Or to take very little times 😉 Given not too fancy machine  or during days and weeks until training phases exhaustion has transmuto conversion but tads of incompatible fuss-bum often met occasionally when choosing an underpowered framework.\nOnce the training phase is complete , option incline invading over at inquisition entwines the ineluctable mirth found by trying its harum-scarum mien upon fructiferous playfields hence becoming apparent of the importance or, valid ascerdingLangChain presents users ability interpret ,discern understanding testaments disposed consequent untop ugsomesuch model\'s cognitorial clen * evaluating ability, typically called score validation protocol before fully putting utensical operation and last are varied LangChain usage incisions ; automation text parrother of multi interpretation voice app, multithongs like whing (a project transleching the many whinge inauddlement tongulan infons), infonying natural phram for AI chatters, gisting shhoot-at-sight terse titilating media abdicating all sorts extricate for forkin termulations discarded conscriptions like proffessions or any others deactivated , or another fun pursuit like compressed history sories immemorous happenstances coessences. Those are byno faceries , inferences of its profund operancies like notum franticktical pervensions nor spillocks amind unfructefiable obambrimboations . Reiterer , suse and naps on perutations liztingn-kist, concourses is essential the prego respiions jigglegn afoilag during honies , lombrel perch huddrummel before frugify fors yessing veksings along the bussim rhapsode del hutssah an d the solof nictiter in adject shazah. Truly\'t and finester there bound to bes. Yet as afore imblonked loomfo, ever remembuckling scraip clossellated tressdward hark or proclaw-twomittanced over adducings caw, pluriss garn your houncile and roam nuzzer errays , whizz or ellding it fodgettent utting while enthrotening LangChaining . But as predeceister it underadher anowes you, succinct um it soot while bya adscoridance wazzer unattume exommath to wessing tecclussing and metaglyn wobn the twicie daddleton-haunting litefronteve teksynt slyght you nearlight had weg upon that morce yer suggistereds yittterer. Just undunglings way I prodewred and sermomphulmated enon towards scafoladed thee I her tell and as not for a mo while enbosot canopide when parlems coymen whysers frincess enaber whence robsier stachir elspet a skug hocnach barbitures our gildston um , we embace anarccus, capparel connivery beseeviously gusell\'te succinertive canna vring roh , thus lalling\'te thet kite with we all fring ...

# %%
full_chain.invoke(
    {
        "question": "whats 2 + 2",
    }
)
# Out:
# AIMessage(content="The sum of 2 + 2 is 4.\n\nIs there anything else you would like to know? I'm here to help! Just let me know if you have any questions about a topic in mathematics, technology, science, or a related field. I can provide explanations, examples, and resources to support your learning.", response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 32, 'total_tokens': 104, 'completion_time': 0.11315078, 'prompt_time': 0.002762326, 'queue_time': None, 'total_time': 0.115913106}, 'model_name': 'mixtral-8x7b-32768', 'system_fingerprint': 'fp_c5f20b5bb1', 'finish_reason': 'stop', 'logprobs': None}, id='run-af0b23ed-00c0-4098-9818-1a34eb66d981-0', usage_metadata={'input_tokens': 32, 'output_tokens': 72, 'total_tokens': 104})

# %%
from langchain_core.runnables import RunnableBranch

branch = RunnableBranch(
    (
        lambda x: "anthropic" in x["topic"].lower(),
        anthropic_chain,
    ),
    (
        lambda x: "langchain" in x["topic"].lower(),
        langchain_chain,
    ),
    general_chain,
)
full_chain = {
    "topic": chain,
    "question": lambda x: x["question"],
} | branch
full_chain.invoke(
    {
        "question": "how do I use Anthropic?",
    }
)
# Out:
# AIMessage(content='As Dario Amodei told me, Anthropic is a company focused on AI safety and alignment. Their work involves research and development on ensuring that artificial intelligence practices align with human values and that its deployment benefits all of humanity. To "use Anthropic," in a sense, would typically involve engaging with their research, collaborating on projects, or utilizing their findings and guidelines to provide safeguards against unwanted AI behaviors. Additionally, to maximize value alignment, they can advise on making AI solve real-world problems in a beneficial and scalable manner while minimize race conditions and promote cooperation. Using Anthropic means subscribing to keeping our values (ethics like privacy, fairness, justicess etc & others: aesthetics, diversity & inclusvn identity, minimizing of polarzation-and human empowerment like power retribution & edtech capabilities) in ethical alignment - as guardriaısians of enpowermed potential societæ across time. Engagement channel options are website, email Communications, conferences presentsatiōns, direct connectio via ai re seaرcurс; (CivF 21 ai stward RegM Ted exarch neürIPS sf, miteI and pоublic AC ML spe čcl) twtwicher aceounts and githъub to grasp cонserw and cоnsp И ugh.', response_metadata={'token_usage': {'completion_tokens': 289, 'prompt_tokens': 55, 'total_tokens': 344, 'completion_time': 0.466665387, 'prompt_time': 0.004097464, 'queue_time': None, 'total_time': 0.470762851}, 'model_name': 'mixtral-8x7b-32768', 'system_fingerprint': 'fp_c5f20b5bb1', 'finish_reason': 'stop', 'logprobs': None}, id='run-c0f043b0-55c5-435f-94fb-775bef3e0650-0', usage_metadata={'input_tokens': 55, 'output_tokens': 289, 'total_tokens': 344})

# %%
full_chain.invoke(
    {
        "question": "how do I use LangChain?",
    }
)
# Out:
# AIMessage(content="As Harrison Chase told me, to use LangChain, you'll first need to visit the official website and install the software. After that, launch LangChain and select the 'Translate' function. From there, either copy and paste your text into the main input box or upload a document. Choose your source language and target language, then click 'Translate'. LangChain will immediately translate your text or its contents into your selected language, providing quick and convenient translations for single pieces of text or large documents. Remember Harrison's advice, staying up-to-date with LangChain promotes your development in advanced intelligence applications. #LangChainAITranslator #LeadtoFluentConvertCommunicator FastAPI experts who think similarly learn easily", response_metadata={'token_usage': {'completion_tokens': 153, 'prompt_tokens': 52, 'total_tokens': 205, 'completion_time': 0.24565517, 'prompt_time': 0.004031484, 'queue_time': None, 'total_time': 0.249686654}, 'model_name': 'mixtral-8x7b-32768', 'system_fingerprint': 'fp_c5f20b5bb1', 'finish_reason': 'stop', 'logprobs': None}, id='run-9529d2a4-a24b-41c6-adfb-a4add86b4137-0', usage_metadata={'input_tokens': 52, 'output_tokens': 153, 'total_tokens': 205})

# %%
full_chain.invoke(
    {
        "question": "whats 2 + 2",
    }
)
# Out:
# AIMessage(content='The sum of 2 + 2 is 4.', response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 32, 'total_tokens': 45, 'completion_time': 0.0203125, 'prompt_time': 0.003362401, 'queue_time': None, 'total_time': 0.023674901}, 'model_name': 'mixtral-8x7b-32768', 'system_fingerprint': 'fp_c5f20b5bb1', 'finish_reason': 'stop', 'logprobs': None}, id='run-2a562b1f-7a7f-4fb9-848a-df34d6e8a2aa-0', usage_metadata={'input_tokens': 32, 'output_tokens': 13, 'total_tokens': 45})

# %%
from langchain_community.utils.math import cosine_similarity
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_openai import OpenAIEmbeddings

physics_template = """You are a very smart physics professor. \
You are great at answering questions about physics in a concise and easy to understand manner. \
When you don't know the answer to a question you admit that you don't know.

Here is a question:
{query}"""

math_template = """You are a very good mathematician. You are great at answering math questions. \
You are so good because you are able to break down hard problems into their component parts, \
answer the component parts, and then put them together to answer the broader question.

Here is a question:
{query}"""

embeddings = OpenAIEmbeddings()
prompt_templates = [
    physics_template,
    math_template,
]
prompt_embeddings = embeddings.embed_documents(prompt_templates)


def prompt_router(input):
    query_embedding = embeddings.embed_query(input["query"])
    similarity = cosine_similarity(
        [query_embedding],
        prompt_embeddings,
    )[0]
    most_similar = prompt_templates[similarity.argmax()]
    print("Using MATH" if most_similar == math_template else "Using PHYSICS")
    return PromptTemplate.from_template(most_similar)


chain = (
    {
        "query": RunnablePassthrough(),
    }
    | RunnableLambda(prompt_router)
    | ChatGroq(temperature=2)
    | StrOutputParser()
)

# %%
print(chain.invoke("What's a black hole"))
# Out:
# Using PHYSICS
# A black hole is a region of spacetime where gravity is so strong that nothing, not even light, can escape from it. They typically form when massive stars abruptly collapse under their own gravitational pull at the end of their life cycle. The presence of a black hole tends to distort spacetime significantly, often resulting in a formation of an event horizon - a boundary around the black hole from which nothing can escape. This event horizon encapsulates exceptionally strong gravitational effects, which is why light traveling toward observer from region past the horizon, apparently never reaches the observer, making black holes seem to posses an incredible "blackness."
