# %%
from langchain_community.llms.loading import load_llm
from langchain_openai import ChatOpenAI, OpenAI


def load_chat_model(filepath):
    """
    Load a chat model from a JSON file.

    Args:
        filepath (str): The path to the JSON file containing the chat model.

    Returns:
        ChatOpenAI: The loaded chat model.
    """
    chat = load_llm(filepath)
    return chat


chat = load_chat_model("example_model.json")

chat

# chat = OpenAI(
#     temperature=0.1,
#     max_tokens=450,
#     model="gpt-3.5-turbo-16k"
# )

# chat.save("example_model.json")
# Out:
# /Users/inw/Desktop/FULLSTACK-GPT/env/lib/python3.9/site-packages/langchain/llms/openai.py:216: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# /Users/inw/Desktop/FULLSTACK-GPT/env/lib/python3.9/site-packages/langchain/llms/openai.py:811: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# OpenAIChat(client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo-16k', model_kwargs={'temperature': 0.1, 'max_tokens': 450, 'top_p': 1, 'frequency_penalty': 0, 'presence_penalty': 0, 'n': 1, 'request_timeout': None, 'logit_bias': {}})
