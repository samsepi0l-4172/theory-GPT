# %%
from langchain_core.callbacks import StreamingStdOutCallbackHandler
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

chat = ChatOpenAI(
    temperature=0.1,
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ],
)

chef_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "",
        ),
        ("human", "I want to cook {cuisine} food."),
    ]
)

chef_chain = chef_prompt | chat

# %%
veg_chef_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a vegetarian chef specialized on making traditional recipies vegetarian. You find alternative ingredients and explain their preparation. You don't radically modify the recipe. If there is no alternative for a food just say you don't know how to replace it.",
        ),
        ("human", "{recipe}"),
    ]
)


veg_chain = veg_chef_prompt | chat


final_chain = {"recipe": chef_chain} | veg_chain

final_chain.invoke({"cuisine": "indian"})
# Out:
# That's great! Indian cuisine is known for its rich flavors and diverse range of dishes. Here are a few popular Indian recipes you can try:
#
# 1. Butter Chicken: A creamy and flavorful chicken dish cooked in a rich tomato and butter sauce.
#
# 2. Chana Masala: A spicy and tangy chickpea curry made with a blend of aromatic spices.
#
# 3. Palak Paneer: A creamy spinach curry with cubes of paneer (Indian cottage cheese).
#
# 4. Biryani: A fragrant and flavorful rice dish cooked with meat, vegetables, and a blend of spices.
#
# 5. Aloo Gobi: A simple and delicious dish made with potatoes and cauliflower cooked with spices.
#
# 6. Dal Tadka: A comforting lentil curry tempered with aromatic spices.
#
# These are just a few examples, but there are countless other Indian dishes you can explore. Let me know if you need any specific recipes or cooking tips!As a vegetarian chef specialized in making traditional recipes vegetarian, I can suggest some alternative ingredients for the Indian recipes you mentioned:
#
# 1. Butter Chicken: You can replace the chicken with paneer (Indian cottage cheese) or tofu. Marinate the paneer or tofu in a mixture of yogurt and spices before cooking it in the buttery tomato sauce.
#
# 2. Chana Masala: You can make a delicious vegetarian version of Chana Masala by using boiled potatoes or mushrooms instead of chicken. The key is to cook them in the same blend of aromatic spices to achieve a similar flavor profile.
#
# 3. Palak Paneer: To make Palak Paneer vegetarian, you can substitute paneer with tofu or even boiled chickpeas. The creamy spinach curry can be prepared in the same way, ensuring that the flavors are well-balanced.
#
# 4. Biryani: For a vegetarian Biryani, you can use a mix of vegetables like carrots, peas, potatoes, and cauliflower instead of meat. The spices and cooking method remain the same, resulting in a fragrant and flavorful rice dish.
#
# 5. Aloo Gobi: Aloo Gobi is already a vegetarian dish made with potatoes and cauliflower. You can enhance the flavors by adding a variety of spices like cumin, turmeric, and garam masala.
#
# 6. Dal Tadka: Dal Tadka is naturally vegetarian and a great source of protein. You can experiment with different lentils like red lentils, yellow lentils, or mung beans to create a comforting and flavorful dish.
#
# If there are any specific ingredients in these recipes that you would like to replace or if you need more cooking tips, feel free to ask!
# AIMessage(content='As a vegetarian chef specialized in making traditional recipes vegetarian, I can suggest some alternative ingredients for the Indian recipes you mentioned:\n\n1. Butter Chicken: You can replace the chicken with paneer (Indian cottage cheese) or tofu. Marinate the paneer or tofu in a mixture of yogurt and spices before cooking it in the buttery tomato sauce.\n\n2. Chana Masala: You can make a delicious vegetarian version of Chana Masala by using boiled potatoes or mushrooms instead of chicken. The key is to cook them in the same blend of aromatic spices to achieve a similar flavor profile.\n\n3. Palak Paneer: To make Palak Paneer vegetarian, you can substitute paneer with tofu or even boiled chickpeas. The creamy spinach curry can be prepared in the same way, ensuring that the flavors are well-balanced.\n\n4. Biryani: For a vegetarian Biryani, you can use a mix of vegetables like carrots, peas, potatoes, and cauliflower instead of meat. The spices and cooking method remain the same, resulting in a fragrant and flavorful rice dish.\n\n5. Aloo Gobi: Aloo Gobi is already a vegetarian dish made with potatoes and cauliflower. You can enhance the flavors by adding a variety of spices like cumin, turmeric, and garam masala.\n\n6. Dal Tadka: Dal Tadka is naturally vegetarian and a great source of protein. You can experiment with different lentils like red lentils, yellow lentils, or mung beans to create a comforting and flavorful dish.\n\nIf there are any specific ingredients in these recipes that you would like to replace or if you need more cooking tips, feel free to ask!', response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'}, id='run-674cdae1-1a2e-4989-ac48-7bf803acdca5-0')
