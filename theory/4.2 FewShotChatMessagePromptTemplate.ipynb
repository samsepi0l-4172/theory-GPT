# %%
from langchain_openai import ChatOpenAI
from langchain.prompts.few_shot import (
    FewShotChatMessagePromptTemplate,
    FewShotChatMessagePromptTemplate,
)
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.prompts import ChatMessagePromptTemplate, ChatPromptTemplate


def run_chat():
    """
    Run a chat conversation using the ChatOpenAI model with a few-shot prompt template.

    This function sets up the chat model, defines example prompts and templates, and invokes the chat model
    with a specific country to get information about it.

    Returns:
        None
    """

    chat = ChatOpenAI(
        temperature=0.1,
        streaming=True,
        callbacks=[
            StreamingStdOutCallbackHandler(),
        ],
    )

    examples = [
        {
            "country": "France",
            "answer": """
            Here is what I know:
            Capital: Paris
            Language: French
            Food: Wine and Cheese
            Currency: Euro
            """,
        },
        {
            "country": "Italy",
            "answer": """
            I know this:
            Capital: Rome
            Language: Italian
            Food: Pizza and Pasta
            Currency: Euro
            """,
        },
        {
            "country": "Greece",
            "answer": """
            I know this:
            Capital: Athens
            Language: Greek
            Food: Souvlaki and Feta Cheese
            Currency: Euro
            """,
        },
    ]

    example_prompt = ChatPromptTemplate.from_messages(
        [
            ("human", "What do you know about {country}?"),
            ("ai", "{answer}"),
        ]
    )

    example_prompt = FewShotChatMessagePromptTemplate(
        example_prompt=example_prompt,
        examples=examples,
    )

    final_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", "You are a geography expert, you given  short answers."),
            example_prompt,
            ("human", "What do you know about {country}?"),
        ]
    )

    chain = final_prompt | chat

    chain.invoke({"country": "Thailand"})


run_chat()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[1], line 87
#      82     chain = final_prompt | chat
#      84     chain.invoke({"country": "Thailand"})
# ---> 87 run_chat()
#
# Cell In[1], line 21, in run_chat()
#      10 def run_chat():
#      11     """
#      12     Run a chat conversation using the ChatOpenAI model with a few-shot prompt template.
#      13
#    (...)
#      18         None
#      19     """
# ---> 21     chat = ChatOpenAI(
#      22         temperature=0.1,
#      23         streaming=True,
#      24         callbacks=[
#      25             StreamingStdOutCallbackHandler(),
#      26         ],
#      27     )
#      29     examples = [
#      30         {
#      31             "country": "France",
#    (...)
#      59         },
#      60     ]
#      62     example_prompt = ChatPromptTemplate.from_messages(
#      63         [
# ...
